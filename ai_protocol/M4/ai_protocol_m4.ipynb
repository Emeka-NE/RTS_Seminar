# %% [markdown]
# # AI Usage Protocol — M4-scientific-communication
#
# **Student:** nnaemeka-nnachi-egwu
# **Course:** Real-Time Systems Seminar — HSHL, Prof. Dr. Stefan Henkler
# **Topic:** Priority Inheritance Protocol (Resource Access Protocols)
# **Exported:** 2026-06-17T17:30:00+02:00
# **Total entries:** 8
#
# This notebook documents all significant AI/LLM interactions during M4-scientific-communication.
# JSON: `ai_protocol_m4.json`

# %%
import json
with open('ai_protocol_m4.json', 'r', encoding='utf-8') as f:
    protocol = json.load(f)
print(f"Milestone: {protocol['milestone']}")
print(f"Entries: {len(protocol['entries'])}")
print(f"Protocol version: {protocol['protocol_version']}")

# %%
print(f"{'ID':<16} {'Status':<22} {'Use':<8} {'Section':<18} {'Objective'}")
print('-'*110)
for entry in protocol['entries']:
    print(f"{entry['id']:<16} {entry['evaluation']['status']:<22} "
          f"{entry['evaluation']['usefulness']:<8} "
          f"{entry['integration']['section']:<18} "
          f"{entry['objective'][:55]}")

# %% [markdown]
# ---
#
# ### `e-m4-001` — Get IEEE LaTeX paper structure advice for the topic
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-17T09:00:00+02:00 |
# | **Parent** | — |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `methodological-check` |
# | **Evaluation status** | `partially-accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 overall |
# | **Usage type** | structure-planning |
# | **Direct text reused** | False |
#
# **Prompt:**
# > i need to write a 5-page IEEE conference paper on PIP for my seminar. what sections should i have and how should i balance them?
#
# **AI Output Summary:**
# Suggested: Abstract, Intro (Kopetz motivation), Background (task model/semaphores), Protocol Landscape (5-protocol table), PIP (formal algo+proofs), UPPAAL, Application Example, Critical Evaluation, Conclusion.
#
# **Verification actions:**
#   - Checked suggestion against M4 checklist requirements: coherent explanation, scientific context, tradeoffs, critical evaluation, AI usage documentation.
#   - Verified section balance: foreground=PIP(§IV), context=Landscape(§III), eval=§VII. Appears balanced.
#   - Note: simulator section was not in original suggestion — added to address 'implementation' requirement from RTS_Seminar slide 4.
#
# **Issues / Corrections:**
#   - Added C++ simulator section (§VI) which was not in AI's suggestion but required by seminar elaboration slide.
#
# **Reflection:**
# The section structure is mostly standard IEEE format. The AI suggestion was a reasonable starting point. The critical addition was the C++ simulator section, which addresses the seminar's explicit requirement for implementation of the main feature. This was not in the AI proposal — I noticed the gap from the seminar slides.

# %% [markdown]
# ---
#
# ### `e-m4-002` — Draft the Abstract concisely summarising PIP's contribution
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-17T10:30:00+02:00 |
# | **Parent** | e-m4-001 |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `primary-source-check` |
# | **Evaluation status** | `partially-accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 Abstract |
# | **Usage type** | drafting |
# | **Direct text reused** | False |
#
# **Prompt:**
# > draft a concise ieee conference abstract for a paper on PIP. must mention: priority inversion, Sha-Rajkumar-Lehoczky, Theorem 7.2, UPPAAL, schedulability analysis. max 150 words.
#
# **AI Output Summary:**
# Produced a 140-word abstract hitting all required points: inversion problem, PIP definition, Theorem 7.2 bound, UPPAAL verification, Liu-Layland + RTA analysis.
#
# **Verification actions:**
#   - Verified every claim in abstract against Buttazzo: Theorem 7.2 (p.219), UPPAAL model (built separately), both schedulability tests (§7.9).
#   - Checked word count: 140 words OK for IEEE conference.
#
# **Issues / Corrections:**
#   - AI phrased it as 'eliminates priority inversion' — WRONG. PIP BOUNDS it, not eliminates it. Corrected to 'bounds priority inversion'.
#
# **Reflection:**
# Found one significant error: 'eliminates' vs 'bounds'. PIP does NOT eliminate priority inversion — it bounds its duration to α_i critical sections. This is a fundamental distinction. Buttazzo is clear: 'PIP limits the priority inversion' (p.214, not 'eliminates'). Corrected in final abstract.

# %% [markdown]
# ---
#
# ### `e-m4-003` — Verify the final page count and get suggestions for reaching exactly 5
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-17T13:00:00+02:00 |
# | **Parent** | — |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `methodological-check` |
# | **Evaluation status** | `accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 §IV,§V,§VI |
# | **Usage type** | drafting |
# | **Direct text reused** | False |
#
# **Prompt:**
# > my paper compiles to 4 pages. i need to reach exactly 5. what content is missing that would genuinely add value, not just filler?
#
# **AI Output Summary:**
# Suggested: (1) Add full pi_wait/pi_signal pseudocode with numbered steps. (2) Add a Gantt-style trace table. (3) Expand UPPAAL model description with variable declarations. (4) Add C++ simulator section with results.
#
# **Verification actions:**
#   - All four suggestions are scientifically legitimate additions, not padding.
#   - Verified that adding pseudocode for pi_wait/pi_signal matches Buttazzo §7.6.4 pp.224-225 exactly.
#   - Gantt table: verified t=0..7 trace numerically before inserting.
#   - UPPAAL variable list: matches pip_model.xml.
#
# **Issues / Corrections:**
#   - (none)
#
# **Reflection:**
# All four expansions are genuine content. The pi_wait/pi_signal pseudocode is particularly important — it is the core of the paper and should be explicit rather than summarised. The Gantt table makes the trace self-contained without requiring the reader to mentally simulate the schedule.

# %% [markdown]
# ---
#
# ### `e-m4-004` — Final cross-check: does the paper cite all 7 references and are BibTeX
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-17T15:30:00+02:00 |
# | **Parent** | — |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `primary-source-check` |
# | **Evaluation status** | `accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 References |
# | **Usage type** | verification-support |
# | **Direct text reused** | False |
#
# **Prompt:**
# > i have 7 bibtex entries. check that all 7 are cited in the paper and the notes describe the connection to PIP correctly
#
# **AI Output Summary:**
# Verified all 7 keys: Buttazzo2011 (cited 20+ times), Sha1990 (6 times, original PIP/PCP paper), Kopetz2011 (intro), Abella2015 (WCET), Gracioli2013 (multiprocessor), Behrmann2004 (UPPAAL), Baker1991 (SRP). All notes accurate.
#
# **Verification actions:**
#   - Traced every \cite{} in the .tex file against the .bib entries.
#   - Verified: Baker1991 appears in Table I (SRP row) and in critical evaluation. Cited ✓.
#   - Verified: Gracioli2013 cited in multiprocessor limitation paragraph. ✓
#   - Verified: pdflatex compile produces no 'undefined reference' warnings. ✓
#   - Cross-checked BibTeX note for Abella2015 against paper conclusion: 'none of the surveyed methods is fully trustworthy' — exact quote matches paper's text (10.txt in zip). ✓
#
# **Issues / Corrections:**
#   - (none)
#
# **Reflection:**
# All 7 references are correctly cited. The BibTeX annotation requirement (seminar slide 2: 'write for each related reference a short note of how it is related') is satisfied. Each BibTeX entry has a 'note' field explaining its specific relevance to PIP, not just a generic description.

# %% [markdown]
# ---
#
# ### `e-m4-005` — Self-check: does the paper integrate M1-M3 milestones rather than bein
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-17T17:00:00+02:00 |
# | **Parent** | — |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `methodological-check` |
# | **Evaluation status** | `accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 overall |
# | **Usage type** | verification-support |
# | **Direct text reused** | False |
#
# **Prompt:**
# > look at my M1, M2, M3 milestone notes and the final paper. does the paper genuinely integrate those milestones? M4 checklist item 1 says it must.
#
# **AI Output Summary:**
# Cross-checked: M1's blocking computation (B1=4, B2=4, B3=0) appears verbatim in paper §VI. M2's application domain section (POSIX/Mars Pathfinder, Gracioli multiprocessor) appears in paper §VII. M3's counterexamples (Fig 7.12 chained, Fig 7.13 deadlock) appear in paper §IV limitations.
#
# **Verification actions:**
#   - Confirmed M1 content appears in §II, §IV, §VI.
#   - Confirmed M2 content appears in §III (landscape), §VII (transfer analysis).
#   - Confirmed M3 content appears in §IV (limitations), §VII (critical eval).
#   - M4 checklist item 1: 'The paper integrates M1-M3 instead of being generated independently' — SATISFIED.
#
# **Issues / Corrections:**
#   - (none)
#
# **Reflection:**
# The integration is genuine: the blocking computation in §VI uses the exact values from M1's open-question resolution (the delta-1 vs delta convention), the Mars Pathfinder example came from M2's POSIX domain section, and the deadlock/chained-blocking limitations in §IV come directly from M3's counterexamples. The paper is a synthesis, not a fresh generation.

# %% [markdown]
# ---
#
# ### `e-m4-006` — Fix the author affiliation block to match university requirements
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-18T09:30:00+02:00 |
# | **Parent** | — |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `primary-source-check` |
# | **Evaluation status** | `accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 author block |
# | **Usage type** | text-revision |
# | **Direct text reused** | False |
#
# **Prompt:**
# > the paper currently has my affiliation wrong. correct format is: Nnaemeka Nnachi-Egwu, Electronic Engineering, Hochschule Hamm-Lippstadt, Lippstadt, Germany. can you show me the exact IEEEtran LaTeX for this?
#
# **AI Output Summary:**
# Provided the IEEEtran multi-line author block with \IEEEauthorblockN for name and \IEEEauthorblockA for affiliation, including department, institution, city/country, and email on separate lines.
#
# **Verification actions:**
#   - Verified against IEEEtran documentation: \IEEEauthorblockN{Name} followed by \IEEEauthorblockA{Department\\Institution\\City, Country\\email}.
#   - Confirmed: department = 'Electronic Engineering', institution = 'Hochschule Hamm-Lippstadt', city = 'Lippstadt, Germany'.
#   - Compiled and verified the author block renders correctly in the PDF.
#
# **Issues / Corrections:**
#   - (none)
#
# **Reflection:**
# Simple fix but important for correctness. The IEEEtran author block format with the correct affiliation is now in the compiled PDF.

# %% [markdown]
# ---
#
# ### `e-m4-007` — Check whether the paper's critical evaluation is balanced enough per t
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-18T11:00:00+02:00 |
# | **Parent** | — |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `methodological-check` |
# | **Evaluation status** | `accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 §VII |
# | **Usage type** | argument-critique |
# | **Direct text reused** | False |
#
# **Prompt:**
# > M4 checklist says 'the paper clearly distinguishes facts, interpretation, critique, and speculation'. can you read my critical evaluation section and flag which claims are facts vs interpretation vs speculation?
#
# **AI Output Summary:**
# Identified: FACTS (with citations): deadlock possible (Fig 7.13), chained blocking possible (Fig 7.12), implementation rated hard (Table 7.5), uniprocessor scope (§7.3). INTERPRETATION (mine, reasoned): WCET sensitivity as a compounded risk, kernel chain traversal latency concern. SPECULATION: chain depth limit in Linux (RTMUTEX_DEPTH_LIMIT=48) — this is from general knowledge, not from Buttazzo or cited papers.
#
# **Verification actions:**
#   - Reviewed every claim in §VII of the paper against the citation list.
#   - WCET sensitivity: grounded in Abella2015 — demoted from speculation to interpretation.
#   - Linux chain depth: removed from main paper text, moved to footnote with 'from general knowledge' qualifier.
#   - Multiprocessor claim: now grounded in Gracioli2013 (Table 1 overhead sources).
#
# **Issues / Corrections:**
#   - (none)
#
# **Reflection:**
# The checklist item about 'distinguishing facts, interpretation, critique, and speculation' is one the professor is likely to ask about in-class. Going through this exercise made me remove one unsubstantiated claim (Linux depth limit as fact) and properly attribute the multiprocessor claim to Gracioli2013 rather than leaving it as assertion.

# %% [markdown]
# ---
#
# ### `e-m4-008` — Verify that the response time analysis calculation in Section VI is sh
#
# | | |
# |---|---|
# | **Timestamp** | 2026-06-18T14:00:00+02:00 |
# | **Parent** | — |
# | **Tool / Model** | Claude / claude-sonnet-4-6 |
# | **Verification level** | `primary-source-check` |
# | **Evaluation status** | `accepted` |
# | **Usefulness** | high |
# | **Used in submitted work** | True |
# | **Section** | M4 §VI |
# | **Usage type** | verification-support |
# | **Direct text reused** | False |
#
# **Prompt:**
# > in section VI of the paper i write R2=8. let me show you my working and you check it: R=C2+B2=2+4=6. iteration 1: R=2+4+ceil(6/6)*1=6+1=7. iteration 2: R=2+4+ceil(7/6)*1=6+2=8. iteration 3: R=2+4+ceil(8/6)*1=6+2=8. converged. is this right?
#
# **AI Output Summary:**
# Yes, that's exactly right. ceil(6/6)=1, ceil(7/6)=2 (since 7/6=1.166...), ceil(8/6)=2 (since 8/6=1.333...). The fixed point is R2=8. For tau3: R=C3+B3=4+0=4; iteration 1: R=4+ceil(4/6)*1+ceil(4/8)*2=4+1+2=7; iteration 2: R=4+ceil(7/6)*1+ceil(7/8)*2=4+2+2=8; iteration 3: same. R3=8≤24. All correct.
#
# **Verification actions:**
#   - Manually verified every ceil() call: ceil(7/6)=ceil(1.167)=2 ✓, ceil(8/6)=ceil(1.333)=2 ✓.
#   - Verified R3: ceil(7/8)=ceil(0.875)=1 ✓. Wait: R at iteration 1 is 7. ceil(7/8)=1. Then R=4+ceil(7/6)*1+ceil(7/8)*2=4+2+2=8. ceil(8/8)=1. R=4+ceil(8/6)*1+ceil(8/8)*2=4+2+2=8. ✓
#   - Cross-checked with Python: math.ceil(8/6)=2, math.ceil(8/8)=1, so R3=4+2+2=8. ✓
#
# **Issues / Corrections:**
#   - (none)
#
# **Reflection:**
# All RTA numbers verified. The step-by-step working is in Deliverable 4 (docs/deliverable4_application_example.md) and the results appear in the paper. tau2 is the interesting case: R2=8=D2 (meets deadline exactly). This demonstrates the exact nature of RTA versus the conservative LL test, which said tau2 was inconclusive.

# %%
import re

def _sb(t):
    t=(t or 'ai').lower()
    return re.sub(r'[^a-z0-9]+','-',t).strip('-') or 'ai'

def _eb(v):
    v=str(v or '')
    for a,b in [('\\','\\textbackslash{}'),'{','\\{'),'}','\\}'),'&','\\&'),'%','\\%'),'$','\\$'),'#','\\#'),'_','\\_')]:
        v=v.replace(a,b)
    return v

p=protocol
year=p.get('exported_at','2026')[:4]
key='-'.join(['ai-usage-protocol',_sb(p.get('student_id','')),_sb(p.get('milestone','')),year])
note=(f"Machine-readable AI protocol; course: {p.get('course','')}; "
      f"version: {p.get('protocol_version','0.2')}; "
      f"entries: {len(p.get('entries',[])) }; json: ai_protocol_m4.json")
bib=(f'@misc{{{key},\n'
     f'  author = {{{_eb(p.get("student_id",""))}}},\n'
     f'  title = {{{_eb(f"AI Usage Protocol for {p.get(chr(109)+chr(105)+chr(108)+chr(101)+chr(115)+chr(116)+chr(111)+chr(110)+chr(101),\"\")}: {p.get(chr(116)+chr(111)+chr(112)+chr(105)+chr(99),\"\")}")}}},\n'
     f'  year = {{{year}}},\n'
     f'  howpublished = {{{{Submitted AI usage protocol notebook and JSON file}}}},\n'
     f'  note = {{{_eb(note)}}}\n}}'
)
print(bib)
